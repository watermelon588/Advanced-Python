# %% [markdown]
# DATE TIME MODULE

# %%
import datetime

# %%
my_time = datetime.time(2,20)

# %%
my_time.minute
# Out:
# 20

# %%
my_time.hour
# Out:
# 2

# %%
print(my_time)
# Out:
# 02:20:00

# %%
New_day = datetime.date.today()

# %%
print(New_day)
# Out:
# 2025-07-21

# %%
New_day.ctime()
# Out:
# 'Mon Jul 21 00:00:00 2025'

# %%
New_day.day
# Out:
# 21

# %%
New_day.year
# Out:
# 2025

# %%
from datetime import datetime

# %%
my_date_time = datetime(2025,7,21,8,37,40)

# %%
print(my_date_time)
# Out:
# 2025-07-21 08:37:40

# %%
my_date_time = my_date_time.replace(minute = 40 , second = 50)

# %%
print(my_date_time)
# Out:
# 2025-07-21 08:40:50

# %%
# date

# %%
from datetime import date

# %%
date_1 = date(2025,7,21)
date_2 = date(2024,7,2)

total = (date_1 - date_2 )

# %%
print(total)
# Out:
# 384 days, 0:00:00

# %%
date_time_1 = datetime(2025,7,21,8,49)
date_time_2 = datetime(2025,1,13,11,4)

diff = (date_time_1 - date_time_2)
print(diff)
# Out:
# 188 days, 21:45:00

# %%
type(diff)
# Out:
# datetime.timedelta

# %%
diff.seconds
# Out:
# 78300

# %%
hour = (diff.seconds /60)/60
hour
# Out:
# 21.75

# %%
diff.total_seconds()
# Out:
# 16321500.0
